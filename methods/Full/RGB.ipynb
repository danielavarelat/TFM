# %%
import yaml
import h5py
import numpy as np
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import nibabel as nib
import pandas as pd
import skimage.io

# %%
multichannel = "/Users/dvarelat/Documents/MASTER/TFM/DATA/0401_E2_RGB.tif"

# %%
multi = skimage.io.imread(multichannel)

# %%
multi.shape
# Out:
# (566, 1024, 1024, 3)

# %%
n = 200
plt.figure(figsize=(20,20)) 
plots = [multi[n, :, :, 0], multi[n, :, :, 1], multi[n,:,:, 2]]
titles =["CHANNEL0", "CHANNEL1", "CHANNEL2"]
for i in range(len(plots)):
    plt.subplot(1,len(plots),i+1).set_title(titles[i]) 
    plt.imshow(plots[i])
plt.show()

# %%
plt.imshow(multi[100, :, :,2])
